# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
from datetime import datetime
from tqdm import tqdm

# %%
# set headers
heads = requests.utils.default_headers()
heads.update({
    'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0',
})

# %%
# helper functions to retrieve detials from thread post
def getUser(header):
    """Attempt to get user from post."""
    user = ''
    user_tag = header.find("a", class_="user")
    if user_tag:
        user = user_tag.get_text()
    return user

def getTimestamp(header):
    """Attempt to get timestamp of post."""
    time = ''
    date = ''
    tag_datetime = header.contents[-1]
    if tag_datetime:
        time = tag_datetime.contents[0].contents[0]
    if len(tag_datetime.contents) == 3:
        date = tag_datetime.contents[-1].contents[0]
    elif len(tag_datetime.contents) == 6:
        date = tag_datetime.contents[2].contents[0] + ' ' + tag_datetime.contents[4].contents[0]
    date_time = '{} {}'.format(date, time) 
    return date_time

def getLikesShares(body):
    """Attempt to get no of likes and shares."""
    likes = ''
    shares = ''
    s_class = body.find("p", class_='s')
    if s_class:
        likes = s_class.find_all('b')[0].get_text()
        shares = s_class.find_all('b')[1].get_text()
    return [likes, shares]

def getQuote(body):
    """Attempt to get quotes from post"""
    quotes = []
    content = body.find('div', class_='narrow')
    blockquotes = content.find_all('blockquote')
    for blockquote in blockquotes:
        a_tag = blockquote.find('a')
        if a_tag:
            _id = a_tag.get('href')
            quotes.append(_id)
    return quotes

def getText(body):
    """Attempt to get text from post"""
    content = body.find('div', class_='narrow')
    text = ''
    while content.blockquote:
        content.blockquote.extract()
    text = content.get_text()
    return text

def getPostID(header):
    """Attempt to get id of post"""
    post_id = ''
    name = header.find_all('a')[0].get('name')
    if name:
        post_id = name
    return post_id

def getGender(header):
    """Attempt to get user from post."""
    gender = ''
    female_tag = header.find("span", class_="f")
    male_tag = header.find("span", class_="m")
    if male_tag:
        gender = male_tag.get_text()
    elif female_tag:
        gender = female_tag.get_text()
    return gender

def parse_post(header, body):
    """retrieve details of each post"""
    post = {}
    post['posted'] = getTimestamp(header)
    post['user'] = getUser(header)
    post['gender'] = getGender(header)
    post['post_id'] = getPostID(header)
    post['text'] = getText(body)
    post['has_quote'] = True if getQuote(body) else False
    post['quotes'] = getQuote(body)
    post['shares'] = getLikesShares(body)[1]
    post['likes'] = getLikesShares(body)[0]
    post['retrieved'] = datetime.now().strftime("%H:%M:%S %d-%m-%Y")
    return post

def is_post_equal(post1, post2):
    return post1 == post2

# %%
def parse_thread(thread):
    """retrieve posts from thread"""
    page = 0 # start from the first page
    next_page = True
    index_post = ''
    previous_index_post = ''

    data = []

    while next_page:
        start_url = 'https://www.nairaland.com/{}/{}'.format(thread, page)
        r1 = requests.get(start_url, heads)
        thread_html = BeautifulSoup(r1.text, 'lxml')

        headers = thread_html.find_all('td', class_='bold l pu')
        bodys = thread_html.find_all('td', class_='l w pd')

        #retrieve first post in the thread
        if len(headers) > 1:
            index_post = getPostID(headers[0]) 

        if page > 0:
            # compare first post on current page with previous page
            if is_post_equal(index_post, previous_index_post):
                break

        for i in range(len(headers)):
            header = headers[i]
            body = bodys[i]
            post = parse_post(header, body)
            post.update({'page_no': page, 'thread':thread})
            data.append(post)
        
        previous_index_post = index_post
        page += 1
    print('Thread: {}, No of Page(s): {}, No of Post(s) {}'.format(thread, page, len(data)))

    return data

# %%
list_of_threads=[5879703,5812390,6052669,5795526, 5812795, 5774874, 6020419, 5760985, 5908926, 5764410, 5744920, 5866113, 5772162, 5762527, 5761835]

# %%
len(list_of_threads)
# Out:
# 15

# %%
parse_thread(5762527)
# Out:
# Thread: 5762527, No of Page(s): 15, No of Post(s) 446
# [{'posted': 'Mar 29 12:19pm',
#   'user': 'SinisterX',
#   'gender': 'm',
#   'post_id': '87885451',
#   'text': 'Coronavirus: A Facebook User’s Experience Of Getting Tested In AbujaATTENTION: PRESIDENCY & FED. MINISTRY OF HEALTH To tell you the truth, NCDC can\'t do anything for you because they are not ready.All this PR they are doing they are assuming people will not try that\'s why.On Wednesday (25/03/2020) I and a colleague of mine decided we want to be sure of our status before going into #selfisolation.So we went through the following steps1. We called the toll free line and after all the normal recorded stories, when we chose to speak to an agent they end the call.2. We went to University of Abuja Teaching Hospital, Gwagwalada, they told us they don\'t do testing there, that the hospital is only an isolation center. They refer us back to NCDC office in town, told us that\'s where testing lab is.3. We drove to NCDC office at Jabi. There are two NCDC offices there in close proximity. The first office told us they don\'t do testing but they directed us to the second office saying that\'s where testing is handled.4. The second office too absolved themselves of that responsibility and directed us to NCDC National Reference Laboratory, Gaduwa.5. We visited the NCDC NRL. On getting there, the security at the gate informed us that a lot of people were there too earlier in the day and were turned away. That they don\'t do testing for individuals unless your state took your sample and submit to them. 6.They refer us to a circular posted at the gate and told us to contact the FCT Epidemiology team lead on COVID-19.7. When I called him  I introduced myself by name and then asked him if he\'s the FCT  team lead on this issue. He answered yes. I then asked him how do I go about getting tested. He asked who are you? Who gave you my number? I told him I\'m an Abuja resident and his number is on a circular at the NCDC  office. He told us he doesn\'t know. He said we should go to NCDC. I told him but they referred us to you. He was silent. I then asked him to advise us. He told us to go to "National Health Disease Control" which doesn\'t exist.I will send a copy of the circular to this forum.Obviously they are doing selective testing which is dangerous.It means a lot of people might have been infected already but for lack of testing they are moving about infecting others.While the information from the official channels are saying people are not coming forth, the truth is that people are going but are been turned away.And I know because I was turned away first hand.It also tells you  that either the NCDC are lying to us or they are not coordinated at all. How will you explain three branches of the office each denying responsibility and pointing us to the next instead of just explaining to us the laid down procedures by the NCDChttps://m.facebook.com/673827759324224/posts/3897292313644403/',
#   'has_quote': False,
#   'quotes': [],
#   'shares': ' 50 Shares',
#   'likes': '382 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 0,
#   'thread': 5762527},
#  {'posted': 'Mar 29 12:29pm',
#   'user': 'ogtavia',
#   'gender': 'm',
#   'post_id': '87885797',
#   'text': 'Have you finally gotten tested? Because I want to get tested. Can we discuss on WhatsApp?',
#   'has_quote': False,
#   'quotes': [],
#   'shares': ' 2 Shares',
#   'likes': '36 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 0,
#   'thread': 5762527},
#  {'posted': 'Mar 29 12:40pm',
#   'user': 'whytepawn1',
#   'gender': 'm',
#   'post_id': '87886186',
#   'text': 'I knew it. It will soon bore down to who you know and your status in the society.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': ' 35 Shares',
#   'likes': '569 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 0,
#   'thread': 5762527},
#  {'posted': 'Mar 29 12:54pm',
#   'user': 'onyotakom',
#   'gender': '',
#   'post_id': '87886615',
#   'text': 'it is official. We are on our own.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': ' 31 Shares',
#   'likes': '485 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 0,
#   'thread': 5762527},
#  {'posted': 'Mar 29 1:05pm',
#   'user': 'SinisterX',
#   'gender': 'm',
#   'post_id': '87886973',
#   'text': 'I got this info from a facebook user (Anon) he just went home to self isolate. I would advice you only go for testing if you’re seeing serious symptoms if not just stay at home',
#   'has_quote': False,
#   'quotes': [],
#   'shares': ' 9 Shares',
#   'likes': '114 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 0,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:24pm',
#   'user': 'Seun',
#   'gender': 'm',
#   'post_id': '87904233',
#   'text': "If this is true, how did they hide it from us? I'm yet to read about any Nairalander based in Nigeria who actually has the Coronavirus Disease....Update: I have seen two. There could be more.",
#   'has_quote': False,
#   'quotes': [],
#   'shares': ' 14 Shares',
#   'likes': '153 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 0,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:29pm',
#   'user': 'EvilPOTATO',
#   'gender': 'm',
#   'post_id': '87904327',
#   'text': 'Treatment would be free',
#   'has_quote': False,
#   'quotes': [],
#   'shares': ' 2 Shares',
#   'likes': '1 Like ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 0,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:29pm',
#   'user': 'Dobson43',
#   'gender': '',
#   'post_id': '87904330',
#   'text': 'This is clueless at its peak. So the figures they keep touting every day is indeed fictional.In other words while they are playing politics with covid one nine birus, the shit is getting real and about to hit the fan',
#   'has_quote': False,
#   'quotes': [],
#   'shares': ' 15 Shares',
#   'likes': '221 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 0,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:29pm',
#   'user': 'Cmanforall',
#   'gender': '',
#   'post_id': '87904331',
#   'text': "OP saying they are doing selective screening is right. Is selective screening appropriate in this kind of situation? YES.Should they use individual's economic or social status for screening? NO!Why are they (NCDC) doing it this way? I don't know.",
#   'has_quote': False,
#   'quotes': [],
#   'shares': ' 1 Share',
#   'likes': '32 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 0,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:29pm',
#   'user': 'JamParkMe',
#   'gender': '',
#   'post_id': '87904332',
#   'text': 'That person seeking a test right now is an unserious fellow. They are only testing those with symptoms such as fever, cough and body aches who may have been exposed to an infected person. There are very limited number of testing kits to go around, so yes of course screening is selective.  Even in America and Europe, they are only testing people with symptoms, so why did your friend think he can just get tested like that?',
#   'has_quote': False,
#   'quotes': [],
#   'shares': ' 12 Shares',
#   'likes': '188 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 0,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:29pm',
#   'user': 'Covid19Control',
#   'gender': '',
#   'post_id': '87904333',
#   'text': "It has been very difficult for average Nigerians in Nigeria to get tested. In most cases, they are screened out as low priority.For this reason, we came together to setup a First-Contact service for average Nigerians.Everything you need to know about our strategy to give full attention to everyone is on our Nairaland thread.We have repeatedly reached out to persons who indicated that they were experiencing certain Covid-19 associated symptoms, offered medical advise, and channeled the data to the responsible government agencies for immediate intervention.Here's a link to our thread - https://www.nairaland.com/5761835/fill-form-experiencing-symptoms-covid-19",
#   'has_quote': False,
#   'quotes': [],
#   'shares': ' 7 Shares',
#   'likes': '24 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 0,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:29pm',
#   'user': 'EvilPOTATO',
#   'gender': 'm',
#   'post_id': '87904336',
#   'text': 'cc Iamj   ',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 0,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:29pm',
#   'user': 'hedonister',
#   'gender': '',
#   'post_id': '87904340',
#   'text': "It's a shame really that we're not ready. Thousands re still waiting to be tested.",
#   'has_quote': False,
#   'quotes': [],
#   'shares': ' 1 Share',
#   'likes': '9 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 0,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:29pm',
#   'user': 'Balenciagaokey',
#   'gender': '',
#   'post_id': '87904352',
#   'text': '',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 0,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:29pm',
#   'user': 'Balenciagaokey',
#   'gender': '',
#   'post_id': '87904360',
#   'text': '',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 0,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:30pm',
#   'user': 'SoliBayNG',
#   'gender': '',
#   'post_id': '87904371',
#   'text': 'Lord help us, because we are all on our own.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '9 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 0,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:30pm',
#   'user': '',
#   'gender': '',
#   'post_id': '87904372',
#   'text': 'May Almighty God continue to be always protecting all securing us from this deadly virus, no matter how its may Almighty God never let it know it direction to our lifes and all our family and friends amen',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '9 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 0,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:30pm',
#   'user': 'Slawormir',
#   'gender': '',
#   'post_id': '87904378',
#   'text': 'Damnnnnn niggarrrIsorightNot only ncdc office can conduct the testhospitals in Abuja, Lagos and Edo have the capacity to test for the virusThat gwagwaladar hospital nor want run am Or rather let them set ncdc lab in each state',
#   'has_quote': False,
#   'quotes': [],
#   'shares': ' 1 Share',
#   'likes': '4 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 0,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:30pm',
#   'user': 'DropsMic',
#   'gender': 'm',
#   'post_id': '87904392',
#   'text': "No surprise here.The cases in Africa are low because we don't have enough testing kits.When the virus was yet to get into Africa instead of our leaders to do the right thing they were busy forming we can handle it.Now see our life.The virus has crippled our economyIt has crippled our health system The few doctors we have are overworked (some are in hiding)Everyone is clueless including the president Africa as a continent just tire me.",
#   'has_quote': False,
#   'quotes': [],
#   'shares': ' 3 Shares',
#   'likes': '63 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 0,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:31pm',
#   'user': 'toffyz',
#   'gender': 'm',
#   'post_id': '87904401',
#   'text': 'Nigeria health workers are one of the most harsh, hot-tempered, negligible,unethical, unprofessional set of people you can ever come across in the whole world. What will it take them to explain to them the reason behind this...or perhaps calm them down by counseling them.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': ' 2 Shares',
#   'likes': '129 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 0,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:31pm',
#   'user': 'Chekwube1989',
#   'gender': 'm',
#   'post_id': '87904404',
#   'text': 'That is Nigeria for u',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 0,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:31pm',
#   'user': 'Emily22',
#   'gender': 'm',
#   'post_id': '87904405',
#   'text': 'O seriousGod sev tire for our matter',
#   'has_quote': False,
#   'quotes': [],
#   'shares': ' 1 Share',
#   'likes': '1 Like ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 0,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:31pm',
#   'user': 'ednut1',
#   'gender': 'm',
#   'post_id': '87904407',
#   'text': 'But Davido could take 32 people along for test plus a governor has done 6 times',
#   'has_quote': False,
#   'quotes': [],
#   'shares': ' 4 Shares',
#   'likes': '132 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 0,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:31pm',
#   'user': 'sammirano',
#   'gender': '',
#   'post_id': '87904409',
#   'text': 'We already know that those figures are bull shi t. Useless govt.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '16 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 0,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:31pm',
#   'user': 'MOVIC6',
#   'gender': '',
#   'post_id': '87904415',
#   'text': 'damn country',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 0,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:32pm',
#   'user': 'sammirano',
#   'gender': '',
#   'post_id': '87904432',
#   'text': 'Those figures are fabricated. One idiot will just wake up and tell them to add a certain no.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': ' 2 Shares',
#   'likes': '62 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 0,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:32pm',
#   'user': 'styless',
#   'gender': 'f',
#   'post_id': '87904442',
#   'text': 'Wawu!',
#   'has_quote': False,
#   'quotes': [],
#   'shares': ' 1 Share',
#   'likes': ' ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 0,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:33pm',
#   'user': 'timocruzcmbb',
#   'gender': 'm',
#   'post_id': '87904451',
#   'text': 'See gobe.he like say them they fear too.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': ' 1 Share',
#   'likes': '2 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 0,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:33pm',
#   'user': 'Salvador1',
#   'gender': '',
#   'post_id': '87904458',
#   'text': 'Chisos Buhari and his clown are fraud',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '5 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 0,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:33pm',
#   'user': 'iPOOPinURmouth',
#   'gender': '',
#   'post_id': '87904462',
#   'text': 'just forget all these testing and shit. the corona stuff is not that serious in africa or let me say nigeria. i can assure you that if they go testing everyone from street to street, we will have atleast 5 positive cases in each street. i do not know of places like island. but for mainland e don spread finish. the fact that we are not seeing breakouts means the virus is not that active on nigerians',
#   'has_quote': False,
#   'quotes': [],
#   'shares': ' 5 Shares',
#   'likes': '61 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 0,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:33pm',
#   'user': 'Beremx',
#   'gender': 'f',
#   'post_id': '87904464',
#   'text': 'It will never catch any nairaland member. How would it catch us when we don’t work again and we are glued to nairaland? It is well  ',
#   'has_quote': False,
#   'quotes': [],
#   'shares': ' 1 Share',
#   'likes': '12 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 0,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:33pm',
#   'user': 'yusufu16',
#   'gender': '',
#   'post_id': '87904466',
#   'text': 'That is the bitter truth.Truth is there are no enough Testing Machine in th country. So they are now doing selective testing.1000s of Nigerians are already carrying and spreading this Virus',
#   'has_quote': False,
#   'quotes': [],
#   'shares': ' 1 Share',
#   'likes': '24 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 0,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:33pm',
#   'user': 'Topmaike007',
#   'gender': 'm',
#   'post_id': '87904467',
#   'text': '',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 1,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:33pm',
#   'user': 'aliumik',
#   'gender': '',
#   'post_id': '87904472',
#   'text': 'Nn',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 1,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:34pm',
#   'user': 'adanny01',
#   'gender': 'm',
#   'post_id': '87904478',
#   'text': 'Its quite obvious the testing is meant for elites only.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '4 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 1,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:34pm',
#   'user': 'Trimque2k1',
#   'gender': '',
#   'post_id': '87904482',
#   'text': 'mumu buhari has killed us...',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '4 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 1,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:34pm',
#   'user': 'Flexzy360',
#   'gender': 'm',
#   'post_id': '87904484',
#   'text': 'Nigerian richest men can donate billionsBut when not properly used, we can not solve the issue at handJust do ur self gud by staying homeTnx u',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '1 Like ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 1,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:34pm',
#   'user': 'Sanfranka6',
#   'gender': 'm',
#   'post_id': '87904485',
#   'text': 'God sees everything, he is not sleeping.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '2 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 1,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:34pm',
#   'user': 'Austineva',
#   'gender': 'm',
#   'post_id': '87904486',
#   'text': 'Terrible! Nigeria is finished finally',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '1 Like ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 1,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:34pm',
#   'user': 'bjgurl',
#   'gender': 'f',
#   'post_id': '87904489',
#   'text': 'They are overwhelmed too as well',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 1,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:34pm',
#   'user': 'Deadratgrill',
#   'gender': '',
#   'post_id': '87904498',
#   'text': 'Isreal just evacuated its citizens today, france or another european country did also some days ago, usa is planning a massive evacuation soon.And i hear some people opening teeth saying from frying pan to fire...u should be asking yourself why are those countries pulling their citizens away or do u honestly believe the number the govt reels out every night like they do during elections?Believe nig govt at your own peril',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '23 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 1,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:35pm',
#   'user': 'UnknownT',
#   'gender': '',
#   'post_id': '87904513',
#   'text': 'They are only testing people thta came back abroad. An SMS they sent me confirmed it this morning.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 1,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:35pm',
#   'user': 'Blackfire',
#   'gender': 'm',
#   'post_id': '87904514',
#   'text': 'Heaven knows I did not vote for this ineptitude epileptic septic govt.Over to those that did corona',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '6 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 1,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:35pm',
#   'user': 'crazycrypto710',
#   'gender': '',
#   'post_id': '87904515',
#   'text': 'In deep sh!t we are.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': ' 1 Share',
#   'likes': '10 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 1,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:35pm',
#   'user': 'Tuska',
#   'gender': '',
#   'post_id': '87904518',
#   'text': 'Nigeria Nah country? The number of people with the disease is very alarming. The government is waiting for people to start dying',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '7 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 1,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:35pm',
#   'user': 'Tunex252',
#   'gender': 'm',
#   'post_id': '87904524',
#   'text': "I'm beginning to ask myself if at all Nigerian is a countryNow I found the answer, we are all living in a ZOO or probably a thick forest with no hope",
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '9 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 1,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:35pm',
#   'user': 'seedorfg',
#   'gender': 'm',
#   'post_id': '87904526',
#   'text': 'Why always we, why always Nigeria like this, no consistency and honesty.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '5 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 1,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:35pm',
#   'user': 'omoteacher',
#   'gender': 'm',
#   'post_id': '87904534',
#   'text': 'Our health workers are all afraid. Maybe they should increase their work hazard allowance in this period ?Naija situation always scare me.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '3 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 1,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:36pm',
#   'user': 'Covid19Control',
#   'gender': '',
#   'post_id': '87904542',
#   'text': 'We hope that you can work with us. We want to be able to reach the ignored people who have been tagged as "low-risk".COVID-19 is very dangerous because it can be spread around, even by healthy asymptomatic people.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '3 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 1,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:36pm',
#   'user': 'LabDNA',
#   'gender': '',
#   'post_id': '87904543',
#   'text': "If we depend on NCDC, we'll die. The only thing that can help us is mass testing. Abott laboratories have developed a molecular-based 5 mins testing machine that are FDA approved. Beg them for the machines.",
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '1 Like ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 1,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:37pm',
#   'user': 'saajus',
#   'gender': '',
#   'post_id': '87904570',
#   'text': 'You are right Op. A lot of people already have it. We have tested just over a thousand, and we have 100+ positives. That\'s whopping 10%. God forbid, if we are going on that 10% rate, that\'s 20m of our population. Italy has 10%, Spain 7%, Iran 7%, United States 1.5% death rate. Those are advanced countries, imagine what could happen in a country that can\'t boast of 1k ventilators, adequate Doctors and Nurses, the death rate can\'t be less than 30%. 30% of 20m is 6m.Our leaders have failed and "aso o bomoye mo". We need a miracle. Is either our immune system help us or weather that won\'t let the virus stay longer on surfaces or supernatural power or the advanced world quickly come out with a solution. In the absence of any of those, we are in a very big soup. Remember, vaccines take at least a year to pass several tests and trials.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': ' 1 Share',
#   'likes': '16 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 1,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:37pm',
#   'user': 'Hustlersguide',
#   'gender': '',
#   'post_id': '87904583',
#   'text': "Good thing is, the elites are most infected with the virus and there is likely a 10% chance of survival.Don't be scared if you're not a member of the elites, nothing will happen to u...God gat ur back.Here's a Prophesy, many politicians will die, Nigeria will start a progressive change not with the likes of Sowore but with new individuals not known in the corridor of power.A young man from Delta State will rise to be more popular and a strong influencer on the political system of the country though he will not sit in Aso rock.Trump will loose the next electionNigeria will eventually be dissolved but not before the progressive change takes place. Nnamdi Kanu is not the Messiah the Igbos have been expectingNiger Delta will not be part of biafra",
#   'has_quote': False,
#   'quotes': [],
#   'shares': ' 1 Share',
#   'likes': '6 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 1,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:38pm',
#   'user': 'COVIK19',
#   'gender': '',
#   'post_id': '87904592',
#   'text': 'Berem Berem, remember that year wey you dey kill us with Buhari matter?',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '1 Like ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 1,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:38pm',
#   'user': 'KaptainAfrika',
#   'gender': '',
#   'post_id': '87904594',
#   'text': '" I and a colleague of mine decided we want to be sure of our status before going into #selfisolation. "1. There are limited test kits.2. You were told that you should go for testing, IF YOU HAVE ANY OF THE SYMPTOMS ! YOU WENT TO GET TESTING, JUST TO BE SURE OF YOUR STATUS!',
#   'has_quote': False,
#   'quotes': [],
#   'shares': ' 1 Share',
#   'likes': '3 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 1,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:38pm',
#   'user': 'ovonramwen',
#   'gender': '',
#   'post_id': '87904601',
#   'text': ' is this the real Seun     . Not sure I’ve seen you comment before now  ',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '4 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 1,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:38pm',
#   'user': 'whitering',
#   'gender': '',
#   'post_id': '87904603',
#   'text': 'I said it, Nigeria is on autopilot since 2015.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': ' 1 Share',
#   'likes': '1 Like ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 1,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:38pm',
#   'user': 'Caleb17',
#   'gender': '',
#   'post_id': '87904605',
#   'text': 'Nigeria has entered once chance. Bill Gates predictions is coming to pass but God forbid. Not my blood nor that of my family and friends....',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '1 Like ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 1,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:38pm',
#   'user': 'jarx',
#   'gender': '',
#   'post_id': '87904621',
#   'text': 'Did you know?\r President Mohammed buhari watched his live broadcast with the rest of us',
#   'has_quote': False,
#   'quotes': [],
#   'shares': ' 2 Shares',
#   'likes': '18 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 1,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:39pm',
#   'user': 'jarx',
#   'gender': '',
#   'post_id': '87904629',
#   'text': 'Did you know?\r President Mohammed buhari watched his live broadcast with the rest of us',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '3 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 1,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:39pm',
#   'user': 'yomi007k',
#   'gender': 'm',
#   'post_id': '87904636',
#   'text': 'Lies. I referred a symptomatic patient this morning  and he got tested today in lagos. He was negative.If you have symptoms and travel history you will get tested.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 1,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:40pm',
#   'user': 'domDva',
#   'gender': 'm',
#   'post_id': '87904643',
#   'text': "The capacity of NCDC is no wear close to what we need in a population of 200m. Germany does over 500k test a week . NCDC does roughly 700 a week and they need to do VIP first ...so just pray you don't get the virus. Simple.",
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '4 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 1,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:40pm',
#   'user': 'Scanfrost',
#   'gender': '',
#   'post_id': '87904645',
#   'text': 'And the idiot came on AIT blowing grammar!! So many incompetent people in High places!! Giving appointment based on tribalism, Godfather!! Am not surprised!! Truth be told Government is not the problem!! We individuals are the sole problem of Nigeria.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '2 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 1,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:40pm',
#   'user': 'princepalace',
#   'gender': 'm',
#   'post_id': '87904649',
#   'text': 'chloroquine, paracetamol and piriton tablets are the antidote for this corona virus. just like every other ailments like typhoid, malaria, jaundice and etc that earlier killed a lot of people, so also this corona virus.  just take the normal dose, the person will get well. i am not afraid of it. taking of herbs made up of dongoyaro, pawpaw leave, mango leave and onion leave will flush the virus away. God has given the solution withing us, we should not panic because it is not a death sentence.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': ' 1 Share',
#   'likes': '11 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 1,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:40pm',
#   'user': 'KingRabota',
#   'gender': '',
#   'post_id': '87904666',
#   'text': 'Politicians should be treated in the hospitals they commissioned. We Nigerians are our problem. By the time we give the vagabonds in power maximum resistance to their indolence a few things will start working in this godforsaken shithole',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '1 Like ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 2,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:40pm',
#   'user': 'SweetCunt97',
#   'gender': 'f',
#   'post_id': '87904667',
#   'text': 'You are one of the problems we have in this country! But if he had indicated that he came back from the states and probably a Northerner, dem go wear protective gear go him house go test am ryt? So only d rich deserves to be tested ryt',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '12 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 2,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:41pm',
#   'user': 'tomju',
#   'gender': 'm',
#   'post_id': '87904669',
#   'text': 'Let them continue with their selective testing. They think they can only test the children of the rich and the rich themselves so they can help them first to stay alive. Truth is Coronavirus dey chase who get plenty money for bank to spend. Mention one poor person in this country who has been tested? None. So I conclude the virus only attacks them...the so called rich and famous. They can keep hoarding testing kits  no problem. God will protect the poor. Selfish people',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '1 Like ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 2,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:41pm',
#   'user': 'Omolomo4eva',
#   'gender': 'm',
#   'post_id': '87904684',
#   'text': 'The bitter truth is dat very soon,we will overtake America since we have been destined to overtake',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '2 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 2,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:41pm',
#   'user': 'Godchosen1',
#   'gender': 'm',
#   'post_id': '87904686',
#   'text': "Nothing Will Work For You In This Country If U Don't Have 'Money' In Collaboration With 'Connection'. Damn Leaders is directly proportional to damn country. mtcheewww......",
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 2,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:42pm',
#   'user': 'Joefat',
#   'gender': '',
#   'post_id': '87904690',
#   'text': "Something is telling me that, this Virus has gone beyond what we think.. If NCDC can be selective about this time.. That me they are only doing it for the wealthy people.. Imagine masses that may have been infected, market women, bus drivers, bike man,students, area boys, slay Queen's, olosho's, smoker's, bear parlour joint and so much more..",
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '1 Like ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 2,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:42pm',
#   'user': 'shogsman',
#   'gender': 'm',
#   'post_id': '87904701',
#   'text': "I keep telling you people that they don't have enough testing kits, I don't even think they have up to 2000 kits in the whole country that is why they are only attending to influential and critical cases.They don't have the resources to test even 0.01 percent of the entire population if they did the number of infected would have ran into thousands by now.Your question now should be how do they hope to treat a disease when they don't even have basic testing kits for the virus.Stay home,wash your hands and avoid unneccesary contact,we are on our own.",
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '2 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 2,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:42pm',
#   'user': 'ZKOSOSO',
#   'gender': 'm',
#   'post_id': '87904705',
#   'text': "Madam!! You're very correct. Eyes are just glued to NL every second....!",
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 2,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:42pm',
#   'user': 'betapikin15',
#   'gender': '',
#   'post_id': '87904707',
#   'text': 'how is selective screening appropriate please??',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '3 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 2,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:42pm',
#   'user': 'Fior',
#   'gender': '',
#   'post_id': '87904708',
#   'text': 'The is only a statement to proof. I trust nothing the govt. is saying, the actual case number is more than we are told...propaganda is their tested and trusted way of leadership.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 2,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:43pm',
#   'user': 'Bluffly',
#   'gender': '',
#   'post_id': '87904711',
#   'text': 'What have they done with the 15 billion Naira released fund',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 2,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:43pm',
#   'user': 'bellotaofeek',
#   'gender': '',
#   'post_id': '87904732',
#   'text': 'Don’t forget the home remedies while u are in isolation. Pineapple peels Lime And Ginger.  Boil thoroughly and take the water morning and night.   And Incase the symptoms are severe.  U can use it to steam up. By facing the boiling stuffs and cover your head with towel . Who knows , it may help. Cos no one care about us.  May God help us. !',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '3 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 2,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:43pm',
#   'user': 'JamParkMe',
#   'gender': '',
#   'post_id': '87904734',
#   'text': "Read my comment and then read it again slowly because your response shows you read but did not comprehend. Anyone returning from a hotspot like U.S, China or Europe should be quarantined, not tested. You only test those manifesting symptoms; it's not about rich or poor.",
#   'has_quote': False,
#   'quotes': [],
#   'shares': ' 1 Share',
#   'likes': '1 Like ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 2,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:44pm',
#   'user': 'Raalsalghul',
#   'gender': '',
#   'post_id': '87904745',
#   'text': 'Can you imagine? ',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '1 Like ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 2,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:45pm',
#   'user': 'Alberto247',
#   'gender': 'm',
#   'post_id': '87904759',
#   'text': 'COVID 19 FEDERAL GOVERNMENT GRANTS. how true is this?',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 2,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:45pm',
#   'user': 'Caleb17',
#   'gender': '',
#   'post_id': '87904762',
#   'text': "Just imagine a hell of an excuse. Our carelessness will soon exposure us. Why are there not enough testing kits upon all the donations. Our case may be worst than that of Italy and spain if God doesn't intervene.",
#   'has_quote': False,
#   'quotes': [],
#   'shares': ' 1 Share',
#   'likes': '2 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 2,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:45pm',
#   'user': 'yaki84',
#   'gender': '',
#   'post_id': '87904767',
#   'text': 'What are u saying? I cannot say',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 2,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:45pm',
#   'user': 'kunkelhanspeter',
#   'gender': 'm',
#   'post_id': '87904769',
#   'text': 'All man for himself',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 2,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:45pm',
#   'user': 'cdyfoundation',
#   'gender': 'm',
#   'post_id': '87904780',
#   'text': "This is Nigeria and not USA or China. The test kits are expensive and we don't have them in surplus.I believe the available ones are reserved for severe cases. But why going about asking for a test when you are perfectly OK. You think this is Malaria or pregnancy test?In the places you went to, there is a high probability of meeting an infected person there than you sitting at home. Don't expose yourself to danger. Be safe.",
#   'has_quote': False,
#   'quotes': [],
#   'shares': ' 1 Share',
#   'likes': '3 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 2,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:45pm',
#   'user': 'Dominatrix',
#   'gender': 'f',
#   'post_id': '87904782',
#   'text': 'Do not feel some type of way about this... But this country of ours has 98% of uneducated, ignorant and most backwards set of people on planet earth! Nigeria has no hope, help yourself and stay safe!',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '2 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 2,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:46pm',
#   'user': 'Microwhy',
#   'gender': '',
#   'post_id': '87904783',
#   'text': 'Since European union and united States urge citizens to leave Nigeria,  I know that things are not right.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '2 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 2,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:46pm',
#   'user': 'EvangelistChuks',
#   'gender': 'm',
#   'post_id': '87904797',
#   'text': 'Jesus is the solution.Dead or alive.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 2,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:46pm',
#   'user': 'hahn',
#   'gender': 'm',
#   'post_id': '87904798',
#   'text': 'Hide what? Their incompetence?You no KNOW say naija no ready?',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '1 Like ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 2,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:46pm',
#   'user': 'BUHARIGOQUENCH',
#   'gender': '',
#   'post_id': '87904805',
#   'text': '..Very dry and useless joke',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 2,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:47pm',
#   'user': 'Mateen1000',
#   'gender': '',
#   'post_id': '87904818',
#   'text': 'I don’t think you have sense at all, How can someone be so daft like this, So the symptoms needs to be very complex before someone get tested, You are sick.And he’s even lying confidently that only people with symptoms are getting tested in US and Europe, You need to be Flogged I swear',
#   'has_quote': False,
#   'quotes': [],
#   'shares': ' 1 Share',
#   'likes': '14 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 2,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:48pm',
#   'user': '',
#   'gender': '',
#   'post_id': '87904823',
#   'text': "Anon what?  no Facebook user with one single name, still searching though, screenshot the user's page so we can at least contact your source.are you sure this is not another lie from Lie Mohammed ?",
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '1 Like ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 2,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:48pm',
#   'user': 'desoul2004',
#   'gender': 'm',
#   'post_id': '87904824',
#   'text': 'If this should be true, then those figures are false.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 2,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:48pm',
#   'user': 'Unserious',
#   'gender': '',
#   'post_id': '87904828',
#   'text': 'You are another problem, they say "Screening is selective" you still dey argue. As a player, if coach no pick you, na to go sidon.This is Nigeria.... Stay Save!',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '1 Like ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 2,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:48pm',
#   'user': 'JamParkMe',
#   'gender': '',
#   'post_id': '87904833',
#   'text': 'You are a clown. So they should use up the limited number of donated testing kits to test healthy individuals at this early phase of the curve? When we reach the apex and have no kits to test those displaying symptoms, what will happen then? In fact by your logic, we should gather all 200 million citizens and start testing them.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': ' 1 Share',
#   'likes': '1 Like ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 2,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:48pm',
#   'user': 'VANZETA',
#   'gender': '',
#   'post_id': '87904837',
#   'text': 'They have been a case, even 2. Quote me let me draw your attention to it.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 2,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:48pm',
#   'user': 'Geofavor',
#   'gender': 'm',
#   'post_id': '87904845',
#   'text': "So, until everyone starts showing the symptoms (and have possibly gotten the virus) before they start testing us? Didn't you hear that most cases are asymptomatic and they spread it the most?",
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '5 Likes ',
#   'retrieved': '17:17:47 18-08-2020',
#   'page_no': 2,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:49pm',
#   'user': 'Bianda24',
#   'gender': '',
#   'post_id': '87904847',
#   'text': 'I know it will come to dis. Nigeria is a zoo,  I am very sure of this.  My advice is that Stay Safe because Nigeria Government has nothing to offer',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '1 Like ',
#   'retrieved': '17:17:48 18-08-2020',
#   'page_no': 3,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:49pm',
#   'user': 'TalkBoutIt',
#   'gender': '',
#   'post_id': '87904849',
#   'text': "Bollocks!!!!!! Germany alone does half a million COVID-19 tests weekly with a population of just above 80 million people, the story about testing kits bring limited us complete nonsense....how would Nigeria not have at least 50,000 test kits on standby?? Is it expensive? At least I know a ventilator cost more than $25,000, and Nigeria as a country don't got 1000 ventilators. Is this a country? Why are you defending mediocrity God  ",
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '7 Likes ',
#   'retrieved': '17:17:48 18-08-2020',
#   'page_no': 3,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:49pm',
#   'user': 'abbey621',
#   'gender': 'm',
#   'post_id': '87904860',
#   'text': 'My advice to most people is to limit exposure to other people and take anti-malaria drugs containing chloroquine at least once. If you continue to rely on this useless government, you are on a long thing. You should know by now that the life of a cow is more important to them than yours, so be wise!',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '3 Likes ',
#   'retrieved': '17:17:48 18-08-2020',
#   'page_no': 3,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:50pm',
#   'user': 'mofedamijo',
#   'gender': 'm',
#   'post_id': '87904865',
#   'text': "I don't know why Nigerians feel they are always the only one facing some issues, read me clearly, there are not enough testing kits all over the world, INCLUDING U.S.A and the U.K, go to any U.K blog, news site, and read thousands of comments about lack of testing kit, as a matter of fact, if U.S and U.K should carry out full test, i can tell you they will have massive massive casualties, this is a global crisis, the NDCD or whatever can't do much, its a global problem.Oga the United States just took delivery of testing kits yesterday, yet they said the kits can't even test Newyork city alone, let alone the whole of Newyork then the whole U.S, no kits available. Demand is super higher than supply.",
#   'has_quote': False,
#   'quotes': [],
#   'shares': ' 1 Share',
#   'likes': '4 Likes ',
#   'retrieved': '17:17:48 18-08-2020',
#   'page_no': 3,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:50pm',
#   'user': '',
#   'gender': '',
#   'post_id': '87904868',
#   'text': 'Why am I not surprised? I knew this is what it will come down to. These people should be ashamed of themselves. This is a national emergency and they\'re still carrying on with "who you know". What a mess',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:48 18-08-2020',
#   'page_no': 3,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:50pm',
#   'user': 'Stmiceel',
#   'gender': 'm',
#   'post_id': '87904870',
#   'text': "If they refuse to test you don't worry. But immediately you see symptoms go back to where they rejected you. Infect them with the virus simple.I'm already in self isolation but they way body dey do me here. I don't want to have a negative feeling. I'm very close to Lagos. I have had contact with someone living around airport in Lagos. He has visited like four times now.I don't want to be negative. If I call the toll free number and they are talking nonsense, I will roll out straight.",
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:48 18-08-2020',
#   'page_no': 3,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:50pm',
#   'user': 'johnmattew',
#   'gender': '',
#   'post_id': '87904882',
#   'text': "what's ur point?.... testing is a problem even in AmericaUSA economy has crumbled....the world is on recession....the health sectors of G8 countries are overworked and insufficient...some Italian doctors and nurses are committing suicide..even America is begging for doctorsdon't make it an African issue",
#   'has_quote': False,
#   'quotes': [],
#   'shares': ' 1 Share',
#   'likes': '2 Likes ',
#   'retrieved': '17:17:48 18-08-2020',
#   'page_no': 3,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:50pm',
#   'user': 'thegloor',
#   'gender': '',
#   'post_id': '87904889',
#   'text': "WHO says TEST TEST TEST. Don't wait for symptoms",
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '1 Like ',
#   'retrieved': '17:17:48 18-08-2020',
#   'page_no': 3,
#   'thread': 5762527},
#  {'posted': 'Mar 29 10:50pm',
#   'user': 'InvertedHammer',
#   'gender': '',
#   'post_id': '87904892',
# ...
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '1 Like ',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 12,
#   'thread': 5762527},
#  {'posted': 'Mar 30 3:10pm',
#   'user': 'JamParkMe',
#   'gender': '',
#   'post_id': '87924843',
#   'text': 'Unfortunately money talks everywhere and not just in Nigeria.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 12,
#   'thread': 5762527},
#  {'posted': 'Mar 30 3:31pm',
#   'user': 'Realtizzy',
#   'gender': 'm',
#   'post_id': '87925519',
#   'text': 'I am not surprisedThat is why everybody should adhere to the lockdown order, it is the only hope of average Nigerian, the so called government agency no send us and by now we should be used to their usual recklessness nd carelessness. We citizens are on our own very wicked , just imagine how the prices of everything has skyrocted but God will save us all .',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '1 Like ',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 12,
#   'thread': 5762527},
#  {'posted': 'Mar 30 3:43pm',
#   'user': 'JamParkMe',
#   'gender': '',
#   'post_id': '87925958',
#   'text': "You are beyond silly. China and Russia is richer than America? God I can't even believe I'm arguing with a slowpoke.",
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 12,
#   'thread': 5762527},
#  {'posted': 'Mar 30 3:53pm',
#   'user': 'JamParkMe',
#   'gender': '',
#   'post_id': '87926301',
#   'text': 'When you and your friends have produced 7 billion testing kits to use and test the whole world, please let us know so every foreign government can buy it from you to test their citizens. Until then, use your thinking faculty and realize that there are limited number of testing kits so therefore only those with symptoms will be tested.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 12,
#   'thread': 5762527},
#  {'posted': 'Mar 30 3:53pm',
#   'user': 'Damntruth',
#   'gender': 'm',
#   'post_id': '87926324',
#   'text': ' China foreign reserves is far more than the USA..how do u quantify rich biko ',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 12,
#   'thread': 5762527},
#  {'posted': 'Mar 30 3:54pm',
#   'user': 'JamParkMe',
#   'gender': '',
#   'post_id': '87926342',
#   'text': "Thank you. They don't think. So quick to criticize the government than think for themselves.",
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 12,
#   'thread': 5762527},
#  {'posted': 'Mar 30 3:55pm',
#   'user': 'JamParkMe',
#   'gender': '',
#   'post_id': '87926377',
#   'text': 'The rich and famous all over the world are getting tested without symptoms. News flash! Life is unfair.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 13,
#   'thread': 5762527},
#  {'posted': 'Mar 30 3:58pm',
#   'user': 'JamParkMe',
#   'gender': '',
#   'post_id': '87926468',
#   'text': 'You are another misinformed idiot. No symptoms, no tests.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 13,
#   'thread': 5762527},
#  {'posted': 'Mar 30 4:01pm',
#   'user': 'JamParkMe',
#   'gender': '',
#   'post_id': '87926586',
#   'text': "Maybe they should've handled it better. But just coming in contact with someone who's infected isn't enough reasons to get tested. No symptoms, no test.",
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 13,
#   'thread': 5762527},
#  {'posted': 'Mar 30 4:04pm',
#   'user': 'JamParkMe',
#   'gender': '',
#   'post_id': '87926693',
#   'text': "Maybe if he had symptoms they will listen to him. We can't speculate what will happen then. But this individual had no symptoms and wanted to get tested. Ain't gonna happen.",
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 13,
#   'thread': 5762527},
#  {'posted': 'Mar 30 4:10pm',
#   'user': 'JamParkMe',
#   'gender': '',
#   'post_id': '87926902',
#   'text': "Yes politicians and head of states must get tested. The last thing you want is mass infection of the executive branch. A nation without a leader or rule of law is an anarchy, you don't want that.",
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 13,
#   'thread': 5762527},
#  {'posted': 'Mar 30 4:11pm',
#   'user': 'clemzo101',
#   'gender': 'm',
#   'post_id': '87926917',
#   'text': 'why are you talking like?',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 13,
#   'thread': 5762527},
#  {'posted': 'Mar 30 4:18pm',
#   'user': 'Legendguru',
#   'gender': '',
#   'post_id': '87927123',
#   'text': 'Hmmm',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 13,
#   'thread': 5762527},
#  {'posted': 'Mar 30 5:06pm',
#   'user': 'gaddafe',
#   'gender': 'm',
#   'post_id': '87928719',
#   'text': "The question here is why is NCDC afraid of explaining this to him if it's as you said?",
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '1 Like ',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 13,
#   'thread': 5762527},
#  {'posted': 'Mar 30 5:59pm',
#   'user': 'DModeCntStopMe',
#   'gender': '',
#   'post_id': '87930325',
#   'text': 'So for your mind now, this country has a leader/leadersI am done with you.Stay safe',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '1 Like ',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 13,
#   'thread': 5762527},
#  {'posted': 'Mar 30 5:59pm',
#   'user': 'vineyardfarms',
#   'gender': '',
#   'post_id': '87930330',
#   'text': ' YOU ARE STUPID',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '1 Like ',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 13,
#   'thread': 5762527},
#  {'posted': 'Mar 30 7:11pm',
#   'user': 'divineappo',
#   'gender': 'm',
#   'post_id': '87932490',
#   'text': "my brother, if u don't av any symptoms, don't go to NCDC oo, u will just go there and catch the virusAm telling u the truth",
#   'has_quote': False,
#   'quotes': [],
#   'shares': ' 1 Share',
#   'likes': '1 Like ',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 13,
#   'thread': 5762527},
#  {'posted': 'Mar 30 10:12pm',
#   'user': 'JamParkMe',
#   'gender': '',
#   'post_id': '87937878',
#   'text': 'Your whole lineage is stupid.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 13,
#   'thread': 5762527},
#  {'posted': 'Mar 30 10:13pm',
#   'user': 'JamParkMe',
#   'gender': '',
#   'post_id': '87937916',
#   'text': 'Of course we have leaders. Is this an anarchy?',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 13,
#   'thread': 5762527},
#  {'posted': 'Mar 30 10:14pm',
#   'user': 'JamParkMe',
#   'gender': '',
#   'post_id': '87937935',
#   'text': "We don't know the full story. Be careful of what you read online.",
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 13,
#   'thread': 5762527},
#  {'posted': 'Mar 30 10:18pm',
#   'user': 'JamParkMe',
#   'gender': '',
#   'post_id': '87938058',
#   'text': 'Read son.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 13,
#   'thread': 5762527},
#  {'posted': 'Mar 30 10:20pm',
#   'user': 'JamParkMe',
#   'gender': '',
#   'post_id': '87938094',
#   'text': 'GDP.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 13,
#   'thread': 5762527},
#  {'posted': 'Mar 30 10:23pm',
#   'user': 'JamParkMe',
#   'gender': '',
#   'post_id': '87938220',
#   'text': "Money talks all over the world. There's a prediction that 80% of Americans will end up contracting this virus and only 0.2% will die from it. This is good news, they will develop antibodies to fight it off it it rears its ugly head again in the future.",
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 13,
#   'thread': 5762527},
#  {'posted': 'Mar 30 10:29pm',
#   'user': 'JamParkMe',
#   'gender': '',
#   'post_id': '87938377',
#   'text': 'Thank you for the PSA, these people really needed it.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 13,
#   'thread': 5762527},
#  {'posted': 'Mar 30 10:49pm',
#   'user': 'Equinophobia',
#   'gender': '',
#   'post_id': '87938893',
#   'text': 'Equinophobia',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 13,
#   'thread': 5762527},
#  {'posted': 'Mar 31 2:14am',
#   'user': 'JamParkMe',
#   'gender': '',
#   'post_id': '87941420',
#   'text': 'Your entire lineage will remain perpetually poor and wretched.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 13,
#   'thread': 5762527},
#  {'posted': 'Mar 31 2:44am',
#   'user': 'darealez',
#   'gender': 'm',
#   'post_id': '87941573',
#   'text': " Two things to note, I had said she showed no symptoms and you had said it's LIKELY she MAY have been displaying symptoms... Never Speculate! I read the broadcast directly from source and I simply cited as expressed. She showed no symptoms.",
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '1 Like ',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 13,
#   'thread': 5762527},
#  {'posted': 'Mar 31 5:41am',
#   'user': 'JamParkMe',
#   'gender': '',
#   'post_id': '87942581',
#   'text': "Ok fine lets assume she showed no symptoms. Are you really shocked that the rich and famous have access to things the average person doesn't? Or you think it only happens in Nigeria?",
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 13,
#   'thread': 5762527},
#  {'posted': 'Mar 31 5:46am',
#   'user': 'JamParkMe',
#   'gender': '',
#   'post_id': '87942608',
#   'text': "Right. Celebrities all over the world will gain access to the testing kits before you and me. That's life for you, it's not just a Nigerian problem. El Rufai and members of the executive branch absolutely should get tested without symptoms of they feel the need for it. A country without its leaders is an anarchy. We don't want that.",
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 13,
#   'thread': 5762527},
#  {'posted': 'Mar 31 5:50am',
#   'user': 'JamParkMe',
#   'gender': '',
#   'post_id': '87942639',
#   'text': 'Lol typical Nigerian. No symptoms, no test.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 13,
#   'thread': 5762527},
#  {'posted': 'Mar 31 5:56am',
#   'user': 'JamParkMe',
#   'gender': '',
#   'post_id': '87942688',
#   'text': "If you don't know, ask nicely and I will tell you. I have family members who are doctors and nurses in the U.S. they are at the frontlines taking care of COVID-19 positive patients. If you have no symptoms, you will not get tested. It's as simple as that. Whatever else you think is just you deceiving yourself. Also be careful about what you read online, OP might be overexagerating.",
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 13,
#   'thread': 5762527},
#  {'posted': 'Mar 31 5:59am',
#   'user': 'JamParkMe',
#   'gender': '',
#   'post_id': '87942720',
#   'text': "Lol, I might even be a carrier and not have any symptoms. But that doesn't make me eligible to get tested. No symptoms, no test.",
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 13,
#   'thread': 5762527},
#  {'posted': 'Mar 31 6:05am',
#   'user': 'JamParkMe',
#   'gender': '',
#   'post_id': '87942765',
#   'text': "Maybe they should've guided him to the right location for the test. Maybe OP is even adding or omitting some details to make his story juicy. But the fact still remains, no symptoms, no test. In regards to Chioma and Davido getting tested without symptoms, it happens all over the world, nothing new here.",
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 13,
#   'thread': 5762527},
#  {'posted': 'Mar 31 6:16am',
#   'user': 'JamParkMe',
#   'gender': '',
#   'post_id': '87942872',
#   'text': "Yes absolutely. In fact you should be worried if members of the executive branch aren't getting tested. If you think the country is bad now, you don't want to be around when  your leaders are wiped out by the virus. So yes they should all get tested.",
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 13,
#   'thread': 5762527},
#  {'posted': 'Mar 31 6:20am',
#   'user': 'JamParkMe',
#   'gender': '',
#   'post_id': '87942913',
#   'text': 'Be careful what you read online. In times like these, social media attention-seekers will prey on the gullible.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 13,
#   'thread': 5762527},
#  {'posted': 'Mar 31 11:45am',
#   'user': 'vineyardfarms',
#   'gender': '',
#   'post_id': '87952492',
#   'text': '@ jamparkme: lt is written in PSALMS 7 V 16.   BACK TO SENDER. BACK TO YOU AND YOUR GENERATION BORN AND UNBORN, IN JESUS NAME.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 13,
#   'thread': 5762527},
#  {'posted': 'Mar 31 12:21pm',
#   'user': 'vineyardfarms',
#   'gender': '',
#   'post_id': '87953750',
#   'text': ' Psalms 109 v 17 - 20.  be your portion and your generation yet unborn.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 13,
#   'thread': 5762527},
#  {'posted': 'Apr 01 7:46am',
#   'user': 'JamParkMe',
#   'gender': '',
#   'post_id': '87978377',
#   'text': 'Your entire lineage living and unborn will still remain perpetually poor and wretched.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 14,
#   'thread': 5762527},
#  {'posted': 'Apr 01 8:16am',
#   'user': 'JamParkMe',
#   'gender': '',
#   'post_id': '87979280',
#   'text': 'But you also said someone can be asymptomatic and test positive. This is true and probably the best scenario because if they get through it without complications they will develop an immunity to it. The protocol still remains, no symptoms, no test. The rich and famous will always circumvent rules in Nigeria and the rest of the world.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '1 Like ',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 14,
#   'thread': 5762527},
#  {'posted': 'Apr 01 4:56pm',
#   'user': 'vineyardfarms',
#   'gender': '',
#   'post_id': '87995337',
#   'text': 'whom God has blessed NO man can curse, therefore your curses that can never be altered or revoked back to you and up to 18th generations.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 14,
#   'thread': 5762527},
#  {'posted': 'Apr 01 8:39pm',
#   'user': 'JamParkMe',
#   'gender': '',
#   'post_id': '88001907',
#   'text': 'Be gone cursed child. You brought this upon yourself.',
#   'has_quote': False,
#   'quotes': [],
#   'shares': '',
#   'likes': '',
#   'retrieved': '17:17:51 18-08-2020',
#   'page_no': 14,
#   'thread': 5762527}]

# %%
# import list of threads from health forum
df_topics = pd.read_csv('../data/raw/health_threads.csv')

# %%
# slice and start from previous collection
df_topics = df_topics[69500:]

# %%
# retrieve posts from each thread
iter = 69500 # start from the previous collection
forum = 'health'
df_posts = pd.DataFrame()
for index, row in tqdm(df_topics.iterrows()):
    res = parse_thread(row['thread_id'])
    df_res = pd.DataFrame(res)
    df_res['forum'] = forum
    df_posts = df_posts.append(df_res)

    iter += 1
    # save after every 500 pages
    if iter % 500 == 0:
        df_posts.to_csv('../data/raw/{}_{}.csv'.format(forum, iter))
df_posts.to_csv('../data/raw/{}.csv'.format(forum))
# Out:
# 4:58,  2.46it/s]Thread: 138668, No of Page(s): 1, No of Post(s) 1
# 32953it [4:04:58,  2.42it/s]Thread: 134576, No of Page(s): 1, No of Post(s) 1
